# %%
#nbextension enable --py --sys-prefix widgetsnbextension
# !pip install gmaps
#nbextension enable --py --sys-prefix gmaps
# Out:
# Requirement already satisfied: gmaps in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (0.9.0)
# Requirement already satisfied: ipython>=5.3.0 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from gmaps) (7.31.1)
# Requirement already satisfied: geojson>=2.0.0 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from gmaps) (2.5.0)
# Requirement already satisfied: traitlets>=4.3.0 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from gmaps) (5.1.1)
# Requirement already satisfied: six in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from gmaps) (1.16.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from gmaps) (7.6.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (3.0.20)
# Requirement already satisfied: matplotlib-inline in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (0.18.1)
# Requirement already satisfied: appnope in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (0.1.2)
# Requirement already satisfied: pygments in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (2.11.2)
# Requirement already satisfied: pexpect>4.3 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (4.8.0)
# Requirement already satisfied: decorator in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (5.1.1)
# Requirement already satisfied: backcall in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (63.4.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.2)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipywidgets>=7.0.0->gmaps) (5.5.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipywidgets>=7.0.0->gmaps) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipywidgets>=7.0.0->gmaps) (1.0.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipywidgets>=7.0.0->gmaps) (6.15.2)
# Requirement already satisfied: pyzmq>=17 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (23.2.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (7.3.5)
# Requirement already satisfied: debugpy>=1.0 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (1.5.1)
# Requirement already satisfied: tornado>=6.1 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.2)
# Requirement already satisfied: psutil in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (5.9.0)
# Requirement already satisfied: packaging in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (21.3)
# Requirement already satisfied: nest-asyncio in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (1.5.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from jedi>=0.16->ipython>=5.3.0->gmaps) (0.8.3)
# Requirement already satisfied: jsonschema>=2.6 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.16.0)
# Requirement already satisfied: jupyter_core in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.11.1)
# Requirement already satisfied: fastjsonschema in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (2.16.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from pexpect>4.3->ipython>=5.3.0->gmaps) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.4.12)
# Requirement already satisfied: importlib-resources>=1.4.0 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (5.2.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (1.3.10)
# Requirement already satisfied: attrs>=17.4.0 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (21.4.0)
# Requirement already satisfied: typing-extensions in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.3.0)
# Requirement already satisfied: importlib-metadata in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.10.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.18.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.2)
# Requirement already satisfied: entrypoints in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (0.4)
# Requirement already satisfied: jinja2 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.3)
# Requirement already satisfied: argon2-cffi in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (21.3.0)
# Requirement already satisfied: prometheus-client in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.14.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.8.0)
# Requirement already satisfied: nbconvert>=5 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.4.4)
# Requirement already satisfied: terminado>=0.8.3 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.13.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from packaging->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (3.0.9)
# Requirement already satisfied: zipp>=3.1.0 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.8.0)
# Requirement already satisfied: defusedxml in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (4.11.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.13)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: bleach in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (4.1.0)
# Requirement already satisfied: testpath in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.6.0)
# Requirement already satisfied: jupyterlab-pygments in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.0.1)
# Requirement already satisfied: argon2-cffi-bindings in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.3.1)
# Requirement already satisfied: webencodings in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: pycparser in /Users/mwehner/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.21)

# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
city_data_to_load = "weather_data/cities.csv"
city_data_df = pd.read_csv(city_data_to_load)
city_data_df.head(10)
# Out:
#    City_ID               City Country                 Date      Lat       Lng  \
# 0        0         Butaritari      KI  2022-11-19 16:07:54   3.0707  172.7902
# 1        1  Llandrindod Wells      GB  2022-11-19 16:07:54  52.2416   -3.3787
# 2        2              Dubbo      AU  2022-11-19 16:07:55 -32.2500  148.6167
# 3        3            Ushuaia      AR  2022-11-19 16:03:37 -54.8000  -68.3000
# 4        4             Marawi      PH  2022-11-19 16:07:55   7.9986  124.2928
# 5        5  Sao Joao Da Barra      BR  2022-11-19 16:07:56 -21.6403  -41.0511
# 6        6            Rikitea      PF  2022-11-19 16:07:57 -23.1203 -134.9692
# 7        7        Tlaltenango      MX  2022-11-19 16:07:57  19.1667  -98.3333
# 8        8        New Norfolk      AU  2022-11-19 16:07:57 -42.7826  147.0587
# 9        9       Punta Arenas      CL  2022-11-19 16:07:58 -53.1500  -70.9167
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     81.16        74          95       16.37
# 1     43.95        85         100        4.47
# 2     71.73        56          75       11.50
# 3     56.82        44          40       17.27
# 4     69.22        95         100        2.28
# 5     75.87        57          82       10.40
# 6     70.18        70         100       12.08
# 7     63.10        55          40        4.61
# 8     56.70        88         100        1.28
# 9     50.11        62          20       34.52

# %%
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]

# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
    
# Assign the figure variable.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)

# Assign the heatmap variable for values greater than 0 degrees.
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp], dissipating=False, max_intensity=300, point_radius=4)

# Add the heatmap layer.
fig.add_layer(heat_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent cloudiness
locations = city_data_df[["Lat", "Lng"]]
clouds = city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=clouds, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent windspeed
locations = city_data_df[["Lat", "Lng"]]
wind = city_data_df["Wind Speed"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=wind, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID               City Country                 Date      Lat  \
# 0         0         Butaritari      KI  2022-11-19 16:07:54   3.0707
# 5         5  Sao Joao Da Barra      BR  2022-11-19 16:07:56 -21.6403
# 16       16               Atar      MR  2022-11-19 16:08:01  20.5169
# 17       17               Sola      VU  2022-11-19 16:08:01 -13.8833
# 21       21       Port Moresby      PG  2022-11-19 16:08:04  -9.4431
# 22       22               Afua      BR  2022-11-19 16:08:04  -0.1567
# 25       25         Varkkallai      IN  2022-11-19 16:08:05   8.7341
# 26       26             Anloga      GH  2022-11-19 16:08:06   5.7947
# 27       27             Talara      PE  2022-11-19 16:08:06  -4.5772
# 37       37             Padang      ID  2022-11-19 16:08:10  -0.9492
#
#          Lng  Max Temp  Humidity  Cloudiness  Wind Speed
# 0   172.7902     81.16        74          95       16.37
# 5   -41.0511     75.87        57          82       10.40
# 16  -13.0499     83.82        21           1       12.59
# 17  167.5500     81.32        73          81        9.95
# 21  147.1797     78.24        89          52        5.59
# 22  -50.3867     89.69        51          93        7.72
# 25   76.7067     82.18        79         100        0.16
# 26    0.8973     83.98        67           9       10.96
# 27  -81.2719     77.76        61           0       11.50
# 37  100.3543     75.25        87         100        3.65

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                  City Country  Max Temp      Lat       Lng Hotel Name
# 0          Butaritari      KI     81.16   3.0707  172.7902
# 5   Sao Joao Da Barra      BR     75.87 -21.6403  -41.0511
# 16               Atar      MR     83.82  20.5169  -13.0499
# 17               Sola      VU     81.32 -13.8833  167.5500
# 21       Port Moresby      PG     78.24  -9.4431  147.1797
# 22               Afua      BR     89.69  -0.1567  -50.3867
# 25         Varkkallai      IN     82.18   8.7341   76.7067
# 26             Anloga      GH     83.98   5.7947    0.8973
# 27             Talara      PE     77.76  -4.5772  -81.2719
# 37             Padang      ID     75.25  -0.9492  100.3543

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    
    # Grab the first hotel from the results and store the name.    
    try: 
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
hotels
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 12.877425, 'lng': 10.4565211},
#     'viewport': {'northeast': {'lat': 12.8787703802915,
#       'lng': 10.4578444302915},
#      'southwest': {'lat': 12.8760724197085, 'lng': 10.4551464697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Government Lodge',
#    'photos': [{'height': 355,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103477038588741184665">Muktar Ahmad</a>'],
#      'photo_reference': 'AW30NDzQ6qt4FLU_LQUXQxRemWWS7jlqMzaN1LWkI2lZkLsXmCydqKqZ0tp7XSaStm8w6umvC9f3xD9XHTFxI3fhiGjFBj4eKzhCLyG37arqYkkq1p31R13mx1uuyOyYicVvvFQVCyUN4AczzL17x1w7sAuFtK1gYNpUF4Hitp52g45h7pNs',
#      'width': 474}],
#    'place_id': 'ChIJuTLghu0jqBERW5DExQZbmf0',
#    'rating': 3.3,
#    'reference': 'ChIJuTLghu0jqBERW5DExQZbmf0',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 4,
#    'vicinity': 'VFG4+XJC, Nguru'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 12.8676625, 'lng': 10.4445997},
#     'viewport': {'northeast': {'lat': 12.8690040302915,
#       'lng': 10.4458419802915},
#      'southwest': {'lat': 12.8663060697085, 'lng': 10.4431440197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Shesons Lodge Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111928910032422013688">Mercy Jayeola (Afrocraft_)</a>'],
#      'photo_reference': 'AW30NDwsOZiUO9_J62rIGL1pcS_33kjsuVANwFaKemlsWs3SOtBL7xPa39PyWMG6PlfcGD9Fg-s1QOXC6yOlxnuZxbg2sizcSEQssGPryC2AcMwqVJ4ENyE2Q5Ro6Vwc3BmbCuDWlD0LnDtXwOwEhDE4tYTuJ-dtHB7RbcjkTjiQY5MYYCzd',
#      'width': 1920}],
#    'place_id': 'ChIJbTCBr9clqBERI7Fpdv4Dx1k',
#    'rating': 3.5,
#    'reference': 'ChIJbTCBr9clqBERI7Fpdv4Dx1k',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 63,
#    'vicinity': 'VC9V+3R9, Canteen Area, Along Old Coca Cola Deport, Nguru'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 12.889818, 'lng': 10.4416761},
#     'viewport': {'northeast': {'lat': 12.8911911302915,
#       'lng': 10.4430433802915},
#      'southwest': {'lat': 12.8884931697085, 'lng': 10.4403454197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'FMC Staffs’ Houses',
#    'place_id': 'ChIJzUm7XyojqBERYgRa79gFSqE',
#    'reference': 'ChIJzUm7XyojqBERYgRa79gFSqE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'VCQR+WMF, Road, Nguru'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 12.8599644, 'lng': 10.4308678},
#     'viewport': {'northeast': {'lat': 12.8613402302915,
#       'lng': 10.4322741802915},
#      'southwest': {'lat': 12.8586422697085, 'lng': 10.4295762197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Central mosque Ngarbi fada',
#    'place_id': 'ChIJX2W3Wj47qBERnYazJSuZMD8',
#    'rating': 3,
#    'reference': 'ChIJX2W3Wj47qBERnYazJSuZMD8',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'VC5J+X8Q, Nguru'}],
#  'status': 'OK'}

# %%
hotels['results']
# Out:
# [{'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 12.877425, 'lng': 10.4565211},
#    'viewport': {'northeast': {'lat': 12.8787703802915,
#      'lng': 10.4578444302915},
#     'southwest': {'lat': 12.8760724197085, 'lng': 10.4551464697085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Government Lodge',
#   'photos': [{'height': 355,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103477038588741184665">Muktar Ahmad</a>'],
#     'photo_reference': 'AW30NDzQ6qt4FLU_LQUXQxRemWWS7jlqMzaN1LWkI2lZkLsXmCydqKqZ0tp7XSaStm8w6umvC9f3xD9XHTFxI3fhiGjFBj4eKzhCLyG37arqYkkq1p31R13mx1uuyOyYicVvvFQVCyUN4AczzL17x1w7sAuFtK1gYNpUF4Hitp52g45h7pNs',
#     'width': 474}],
#   'place_id': 'ChIJuTLghu0jqBERW5DExQZbmf0',
#   'rating': 3.3,
#   'reference': 'ChIJuTLghu0jqBERW5DExQZbmf0',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 4,
#   'vicinity': 'VFG4+XJC, Nguru'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 12.8676625, 'lng': 10.4445997},
#    'viewport': {'northeast': {'lat': 12.8690040302915,
#      'lng': 10.4458419802915},
#     'southwest': {'lat': 12.8663060697085, 'lng': 10.4431440197085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Shesons Lodge Hotel',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1080,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111928910032422013688">Mercy Jayeola (Afrocraft_)</a>'],
#     'photo_reference': 'AW30NDwsOZiUO9_J62rIGL1pcS_33kjsuVANwFaKemlsWs3SOtBL7xPa39PyWMG6PlfcGD9Fg-s1QOXC6yOlxnuZxbg2sizcSEQssGPryC2AcMwqVJ4ENyE2Q5Ro6Vwc3BmbCuDWlD0LnDtXwOwEhDE4tYTuJ-dtHB7RbcjkTjiQY5MYYCzd',
#     'width': 1920}],
#   'place_id': 'ChIJbTCBr9clqBERI7Fpdv4Dx1k',
#   'rating': 3.5,
#   'reference': 'ChIJbTCBr9clqBERI7Fpdv4Dx1k',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 63,
#   'vicinity': 'VC9V+3R9, Canteen Area, Along Old Coca Cola Deport, Nguru'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 12.889818, 'lng': 10.4416761},
#    'viewport': {'northeast': {'lat': 12.8911911302915,
#      'lng': 10.4430433802915},
#     'southwest': {'lat': 12.8884931697085, 'lng': 10.4403454197085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'FMC Staffs’ Houses',
#   'place_id': 'ChIJzUm7XyojqBERYgRa79gFSqE',
#   'reference': 'ChIJzUm7XyojqBERYgRa79gFSqE',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'vicinity': 'VCQR+WMF, Road, Nguru'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 12.8599644, 'lng': 10.4308678},
#    'viewport': {'northeast': {'lat': 12.8613402302915,
#      'lng': 10.4322741802915},
#     'southwest': {'lat': 12.8586422697085, 'lng': 10.4295762197085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'icon_background_color': '#909CE1',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#   'name': 'Central mosque Ngarbi fada',
#   'place_id': 'ChIJX2W3Wj47qBERnYazJSuZMD8',
#   'rating': 3,
#   'reference': 'ChIJX2W3Wj47qBERnYazJSuZMD8',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 2,
#   'vicinity': 'VC5J+X8Q, Nguru'}]

# %%
hotels["results"][0]
# Out:
# {'business_status': 'OPERATIONAL',
#  'geometry': {'location': {'lat': 12.877425, 'lng': 10.4565211},
#   'viewport': {'northeast': {'lat': 12.8787703802915, 'lng': 10.4578444302915},
#    'southwest': {'lat': 12.8760724197085, 'lng': 10.4551464697085}}},
#  'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#  'icon_background_color': '#909CE1',
#  'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#  'name': 'Government Lodge',
#  'photos': [{'height': 355,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103477038588741184665">Muktar Ahmad</a>'],
#    'photo_reference': 'AW30NDzQ6qt4FLU_LQUXQxRemWWS7jlqMzaN1LWkI2lZkLsXmCydqKqZ0tp7XSaStm8w6umvC9f3xD9XHTFxI3fhiGjFBj4eKzhCLyG37arqYkkq1p31R13mx1uuyOyYicVvvFQVCyUN4AczzL17x1w7sAuFtK1gYNpUF4Hitp52g45h7pNs',
#    'width': 474}],
#  'place_id': 'ChIJuTLghu0jqBERW5DExQZbmf0',
#  'rating': 3.3,
#  'reference': 'ChIJuTLghu0jqBERW5DExQZbmf0',
#  'scope': 'GOOGLE',
#  'types': ['lodging', 'point_of_interest', 'establishment'],
#  'user_ratings_total': 4,
#  'vicinity': 'VFG4+XJC, Nguru'}

# %%
hotel_df.head()
# Out:
#                  City Country  Max Temp      Lat       Lng  \
# 0          Butaritari      KI     81.16   3.0707  172.7902
# 5   Sao Joao Da Barra      BR     75.87 -21.6403  -41.0511
# 16               Atar      MR     83.82  20.5169  -13.0499
# 17               Sola      VU     81.32 -13.8833  167.5500
# 21       Port Moresby      PG     78.24  -9.4431  147.1797
#
#                      Hotel Name
# 0            Isles Sunset Lodge
# 5       Pousada Porto De Canoas
# 16               Oumou Elghoura
# 17           Leumerus Bungalows
# 21  Lamana Hotel (Port Moresby)

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
