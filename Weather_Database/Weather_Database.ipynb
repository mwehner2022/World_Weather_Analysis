# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 773

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]      
        city_weather_discription = city_weather["weather"][0]["description"]    
        # Append the city information into the city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_discription})
    
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | sao filipe
# Processing Record 3 of Set 1 | torbay
# Processing Record 4 of Set 1 | blackwater
# Processing Record 5 of Set 1 | saint george
# Processing Record 6 of Set 1 | arraial do cabo
# Processing Record 7 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 1 | ancud
# Processing Record 9 of Set 1 | beringovskiy
# Processing Record 10 of Set 1 | hermanus
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 1 | kodiak
# Processing Record 15 of Set 1 | vuktyl
# Processing Record 16 of Set 1 | umea
# Processing Record 17 of Set 1 | lagoa
# Processing Record 18 of Set 1 | lebu
# Processing Record 19 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 20 of Set 1 | luderitz
# Processing Record 21 of Set 1 | areka
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | khatanga
# Processing Record 24 of Set 1 | mendeleyevsk
# Processing Record 25 of Set 1 | tasiilaq
# Processing Record 26 of Set 1 | bugiri
# Processing Record 27 of Set 1 | cabo san lucas
# Processing Record 28 of Set 1 | longyearbyen
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | carroll
# Processing Record 31 of Set 1 | ilulissat
# Processing Record 32 of Set 1 | kasongo
# Processing Record 33 of Set 1 | samana
# Processing Record 34 of Set 1 | kudahuvadhoo
# Processing Record 35 of Set 1 | atuona
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | yellowknife
# Processing Record 39 of Set 1 | lujan
# Processing Record 40 of Set 1 | georgetown
# Processing Record 41 of Set 1 | avarua
# Processing Record 42 of Set 1 | yulara
# Processing Record 43 of Set 1 | port alfred
# Processing Record 44 of Set 1 | hegra
# Processing Record 45 of Set 1 | chokurdakh
# Processing Record 46 of Set 1 | aklavik
# Processing Record 47 of Set 1 | turinsk
# Processing Record 48 of Set 1 | pangnirtung
# Processing Record 49 of Set 1 | victoria
# Processing Record 50 of Set 1 | bambous virieux
# Processing Record 1 of Set 2 | katsuura
# Processing Record 2 of Set 2 | rodrigues alves
# Processing Record 3 of Set 2 | tiksi
# Processing Record 4 of Set 2 | ashqelon
# Processing Record 5 of Set 2 | rikitea
# Processing Record 6 of Set 2 | vaini
# Processing Record 7 of Set 2 | bonthe
# Processing Record 8 of Set 2 | hobyo
# Processing Record 9 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 2 | hithadhoo
# Processing Record 11 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 2 | coxim
# Processing Record 13 of Set 2 | san quintin
# Processing Record 14 of Set 2 | sumbawa
# City not found. Skipping...
# Processing Record 15 of Set 2 | hilo
# Processing Record 16 of Set 2 | manavalakurichi
# Processing Record 17 of Set 2 | thompson
# Processing Record 18 of Set 2 | jiexiu
# Processing Record 19 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 2 | mount isa
# Processing Record 21 of Set 2 | hobart
# Processing Record 22 of Set 2 | padang
# Processing Record 23 of Set 2 | saint anthony
# Processing Record 24 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 2 | cidreira
# Processing Record 26 of Set 2 | bengkulu
# Processing Record 27 of Set 2 | hami
# Processing Record 28 of Set 2 | qaanaaq
# Processing Record 29 of Set 2 | mahebourg
# Processing Record 30 of Set 2 | tura
# Processing Record 31 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 32 of Set 2 | tuktoyaktuk
# Processing Record 33 of Set 2 | vostok
# Processing Record 34 of Set 2 | mitu
# Processing Record 35 of Set 2 | lodwar
# Processing Record 36 of Set 2 | cape town
# Processing Record 37 of Set 2 | ostersund
# Processing Record 38 of Set 2 | takoradi
# Processing Record 39 of Set 2 | san patricio
# Processing Record 40 of Set 2 | mlowo
# Processing Record 41 of Set 2 | addis zemen
# City not found. Skipping...
# Processing Record 42 of Set 2 | bredasdorp
# Processing Record 43 of Set 2 | nome
# Processing Record 44 of Set 2 | wenzhou
# Processing Record 45 of Set 2 | horsham
# Processing Record 46 of Set 2 | ribeira grande
# Processing Record 47 of Set 2 | geraldton
# Processing Record 48 of Set 2 | kaeo
# Processing Record 49 of Set 2 | kokoda
# Processing Record 50 of Set 2 | galiwinku
# City not found. Skipping...
# Processing Record 1 of Set 3 | narsaq
# Processing Record 2 of Set 3 | mnogovershinnyy
# Processing Record 3 of Set 3 | cherskiy
# Processing Record 4 of Set 3 | bluff
# Processing Record 5 of Set 3 | nanortalik
# Processing Record 6 of Set 3 | gizo
# Processing Record 7 of Set 3 | caxhuacan
# Processing Record 8 of Set 3 | esmeralda
# Processing Record 9 of Set 3 | puerto leguizamo
# Processing Record 10 of Set 3 | muravlenko
# Processing Record 11 of Set 3 | mar del plata
# Processing Record 12 of Set 3 | severo-kurilsk
# Processing Record 13 of Set 3 | pangkalanbuun
# Processing Record 14 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 3 | souillac
# Processing Record 16 of Set 3 | jatiroto
# Processing Record 17 of Set 3 | nikolskoye
# Processing Record 18 of Set 3 | luganville
# Processing Record 19 of Set 3 | rio gallegos
# Processing Record 20 of Set 3 | beloha
# Processing Record 21 of Set 3 | adrar
# Processing Record 22 of Set 3 | imbituba
# Processing Record 23 of Set 3 | castro
# Processing Record 24 of Set 3 | tuggurt
# City not found. Skipping...
# Processing Record 25 of Set 3 | mutsamudu
# City not found. Skipping...
# Processing Record 26 of Set 3 | salalah
# Processing Record 27 of Set 3 | dien bien
# City not found. Skipping...
# Processing Record 28 of Set 3 | lardos
# Processing Record 29 of Set 3 | san cristobal
# Processing Record 30 of Set 3 | koradacheri
# City not found. Skipping...
# Processing Record 31 of Set 3 | dikson
# Processing Record 32 of Set 3 | kruisfontein
# Processing Record 33 of Set 3 | saint-philippe
# Processing Record 34 of Set 3 | bowen
# Processing Record 35 of Set 3 | puerto madryn
# Processing Record 36 of Set 3 | miracema do tocantins
# Processing Record 37 of Set 3 | nuevo casas grandes
# Processing Record 38 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 3 | butaritari
# Processing Record 40 of Set 3 | mairang
# Processing Record 41 of Set 3 | atar
# Processing Record 42 of Set 3 | bac lieu
# Processing Record 43 of Set 3 | piacabucu
# Processing Record 44 of Set 3 | chokwe
# Processing Record 45 of Set 3 | cleethorpes
# Processing Record 46 of Set 3 | huarmey
# Processing Record 47 of Set 3 | puerto ayora
# Processing Record 48 of Set 3 | opuwo
# Processing Record 49 of Set 3 | los llanos de aridane
# Processing Record 50 of Set 3 | upernavik
# Processing Record 1 of Set 4 | turukhansk
# Processing Record 2 of Set 4 | markova
# Processing Record 3 of Set 4 | atambua
# Processing Record 4 of Set 4 | vardo
# Processing Record 5 of Set 4 | manaus
# Processing Record 6 of Set 4 | sitka
# Processing Record 7 of Set 4 | hasaki
# Processing Record 8 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 9 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 4 | mareeba
# Processing Record 11 of Set 4 | tecoanapa
# Processing Record 12 of Set 4 | vila velha
# Processing Record 13 of Set 4 | gambat
# Processing Record 14 of Set 4 | nokha
# Processing Record 15 of Set 4 | bukama
# Processing Record 16 of Set 4 | kabalo
# Processing Record 17 of Set 4 | ostrovnoy
# Processing Record 18 of Set 4 | bonavista
# Processing Record 19 of Set 4 | abalak
# Processing Record 20 of Set 4 | santo angelo
# Processing Record 21 of Set 4 | berlevag
# Processing Record 22 of Set 4 | comrie
# Processing Record 23 of Set 4 | san ramon
# Processing Record 24 of Set 4 | miedzyrzec podlaski
# Processing Record 25 of Set 4 | coihaique
# Processing Record 26 of Set 4 | kysyl-syr
# Processing Record 27 of Set 4 | basco
# Processing Record 28 of Set 4 | aktau
# Processing Record 29 of Set 4 | diamantina
# Processing Record 30 of Set 4 | camacha
# Processing Record 31 of Set 4 | urumqi
# Processing Record 32 of Set 4 | sabha
# Processing Record 33 of Set 4 | chaozhou
# Processing Record 34 of Set 4 | tabou
# Processing Record 35 of Set 4 | biskamzha
# Processing Record 36 of Set 4 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 37 of Set 4 | fortuna
# Processing Record 38 of Set 4 | chitral
# Processing Record 39 of Set 4 | klaksvik
# Processing Record 40 of Set 4 | tual
# Processing Record 41 of Set 4 | mecca
# Processing Record 42 of Set 4 | roald
# Processing Record 43 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 44 of Set 4 | korla
# Processing Record 45 of Set 4 | mattru
# Processing Record 46 of Set 4 | santa cruz de tenerife
# Processing Record 47 of Set 4 | itatskiy
# Processing Record 48 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 4 | mahajanga
# Processing Record 1 of Set 5 | macaboboni
# City not found. Skipping...
# Processing Record 2 of Set 5 | srednekolymsk
# Processing Record 3 of Set 5 | saskatoon
# Processing Record 4 of Set 5 | nantucket
# Processing Record 5 of Set 5 | broken hill
# Processing Record 6 of Set 5 | kutum
# Processing Record 7 of Set 5 | batticaloa
# Processing Record 8 of Set 5 | goderich
# Processing Record 9 of Set 5 | barrow
# Processing Record 10 of Set 5 | cuajinicuilapa
# Processing Record 11 of Set 5 | carnarvon
# Processing Record 12 of Set 5 | dakar
# Processing Record 13 of Set 5 | karratha
# Processing Record 14 of Set 5 | kiruna
# Processing Record 15 of Set 5 | esperance
# Processing Record 16 of Set 5 | dunedin
# Processing Record 17 of Set 5 | khani
# Processing Record 18 of Set 5 | port lincoln
# Processing Record 19 of Set 5 | sao sebastiao
# Processing Record 20 of Set 5 | provideniya
# Processing Record 21 of Set 5 | balkanabat
# Processing Record 22 of Set 5 | port macquarie
# Processing Record 23 of Set 5 | acari
# Processing Record 24 of Set 5 | byron bay
# Processing Record 25 of Set 5 | neuquen
# Processing Record 26 of Set 5 | hede
# Processing Record 27 of Set 5 | airai
# Processing Record 28 of Set 5 | udachnyy
# Processing Record 29 of Set 5 | pascagoula
# Processing Record 30 of Set 5 | lorengau
# Processing Record 31 of Set 5 | meulaboh
# Processing Record 32 of Set 5 | solna
# Processing Record 33 of Set 5 | nara
# Processing Record 34 of Set 5 | havelock
# Processing Record 35 of Set 5 | teya
# Processing Record 36 of Set 5 | tuatapere
# Processing Record 37 of Set 5 | chuy
# Processing Record 38 of Set 5 | khandyga
# Processing Record 39 of Set 5 | plavinas
# Processing Record 40 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 5 | bayan
# Processing Record 42 of Set 5 | saskylakh
# Processing Record 43 of Set 5 | devils lake
# Processing Record 44 of Set 5 | xixiang
# Processing Record 45 of Set 5 | hambantota
# Processing Record 46 of Set 5 | cairns
# Processing Record 47 of Set 5 | nyurba
# Processing Record 48 of Set 5 | port keats
# Processing Record 49 of Set 5 | krasnoselkup
# Processing Record 50 of Set 5 | rawson
# Processing Record 1 of Set 6 | leningradskiy
# Processing Record 2 of Set 6 | dera din panah
# City not found. Skipping...
# Processing Record 3 of Set 6 | barroualie
# City not found. Skipping...
# Processing Record 4 of Set 6 | arlit
# Processing Record 5 of Set 6 | buala
# Processing Record 6 of Set 6 | antanifotsy
# Processing Record 7 of Set 6 | biak
# Processing Record 8 of Set 6 | alyangula
# Processing Record 9 of Set 6 | kaitangata
# Processing Record 10 of Set 6 | port augusta
# Processing Record 11 of Set 6 | codrington
# Processing Record 12 of Set 6 | beldanga
# Processing Record 13 of Set 6 | marrakesh
# Processing Record 14 of Set 6 | walvis bay
# Processing Record 15 of Set 6 | payakumbuh
# Processing Record 16 of Set 6 | belmonte
# Processing Record 17 of Set 6 | vao
# Processing Record 18 of Set 6 | arrecife
# Processing Record 19 of Set 6 | dubbo
# Processing Record 20 of Set 6 | lisala
# Processing Record 21 of Set 6 | panshi
# Processing Record 22 of Set 6 | honiara
# Processing Record 23 of Set 6 | luwuk
# Processing Record 24 of Set 6 | namatanai
# Processing Record 25 of Set 6 | kalmunai
# Processing Record 26 of Set 6 | new norfolk
# Processing Record 27 of Set 6 | husavik
# Processing Record 28 of Set 6 | ituni
# City not found. Skipping...
# Processing Record 29 of Set 6 | preili
# Processing Record 30 of Set 6 | hervey bay
# Processing Record 31 of Set 6 | kozhevnikovo
# Processing Record 32 of Set 6 | ornes
# Processing Record 33 of Set 6 | nishihara
# Processing Record 34 of Set 6 | bolshiye uki
# City not found. Skipping...
# Processing Record 35 of Set 6 | oriximina
# Processing Record 36 of Set 6 | iqaluit
# Processing Record 37 of Set 6 | killybegs
# Processing Record 38 of Set 6 | mount gambier
# Processing Record 39 of Set 6 | linden
# Processing Record 40 of Set 6 | general pico
# Processing Record 41 of Set 6 | goure
# Processing Record 42 of Set 6 | alekseyevsk
# Processing Record 43 of Set 6 | sierra vista
# Processing Record 44 of Set 6 | bundaberg
# Processing Record 45 of Set 6 | pevek
# Processing Record 46 of Set 6 | kavieng
# Processing Record 47 of Set 6 | labuhan
# Processing Record 48 of Set 6 | zhigansk
# Processing Record 49 of Set 6 | villazon
# Processing Record 50 of Set 6 | mahaicony
# City not found. Skipping...
# Processing Record 1 of Set 7 | lasa
# Processing Record 2 of Set 7 | peterhead
# Processing Record 3 of Set 7 | puerto ayacucho
# Processing Record 4 of Set 7 | sakakah
# Processing Record 5 of Set 7 | yuksekova
# Processing Record 6 of Set 7 | yar-sale
# Processing Record 7 of Set 7 | ambilobe
# Processing Record 8 of Set 7 | upanema
# Processing Record 9 of Set 7 | ewa beach
# Processing Record 10 of Set 7 | bilibino
# Processing Record 11 of Set 7 | rolim de moura
# City not found. Skipping...
# Processing Record 12 of Set 7 | kursavka
# Processing Record 13 of Set 7 | bandarbeyla
# Processing Record 14 of Set 7 | energetik
# Processing Record 15 of Set 7 | shache
# Processing Record 16 of Set 7 | caravelas
# Processing Record 17 of Set 7 | shenjiamen
# Processing Record 18 of Set 7 | la grande
# Processing Record 19 of Set 7 | osmena
# Processing Record 20 of Set 7 | sukhobuzimskoye
# Processing Record 21 of Set 7 | kahului
# Processing Record 22 of Set 7 | outjo
# Processing Record 23 of Set 7 | axim
# Processing Record 24 of Set 7 | ixtapa
# Processing Record 25 of Set 7 | bethel
# Processing Record 26 of Set 7 | panguipulli
# Processing Record 27 of Set 7 | oranjemund
# Processing Record 28 of Set 7 | bushehr
# Processing Record 29 of Set 7 | orlik
# Processing Record 30 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 7 | pingliang
# Processing Record 32 of Set 7 | sola
# Processing Record 33 of Set 7 | riberalta
# Processing Record 34 of Set 7 | sinnamary
# Processing Record 35 of Set 7 | celestun
# Processing Record 36 of Set 7 | krasnoarmeysk
# Processing Record 37 of Set 7 | sterling
# Processing Record 38 of Set 7 | atasu
# Processing Record 39 of Set 7 | clinton
# Processing Record 40 of Set 7 | gold coast
# Processing Record 41 of Set 7 | borovichi
# Processing Record 42 of Set 7 | port elizabeth
# Processing Record 43 of Set 7 | guerrero negro
# Processing Record 44 of Set 7 | cheuskiny
# City not found. Skipping...
# Processing Record 45 of Set 7 | samarai
# Processing Record 46 of Set 7 | ahipara
# Processing Record 47 of Set 7 | dodoma
# Processing Record 48 of Set 7 | leshukonskoye
# Processing Record 49 of Set 7 | port-gentil
# Processing Record 50 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 1 of Set 8 | tianpeng
# Processing Record 2 of Set 8 | chiredzi
# Processing Record 3 of Set 8 | batagay-alyta
# Processing Record 4 of Set 8 | merauke
# Processing Record 5 of Set 8 | tecpatan
# Processing Record 6 of Set 8 | shingu
# Processing Record 7 of Set 8 | kemijarvi
# Processing Record 8 of Set 8 | charters towers
# Processing Record 9 of Set 8 | madaoua
# Processing Record 10 of Set 8 | anadyr
# Processing Record 11 of Set 8 | lazaro cardenas
# Processing Record 12 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 8 | faanui
# Processing Record 15 of Set 8 | egvekinot
# Processing Record 16 of Set 8 | northam
# Processing Record 17 of Set 8 | den helder
# Processing Record 18 of Set 8 | kovdor
# Processing Record 19 of Set 8 | ust-kuyga
# Processing Record 20 of Set 8 | ust-karsk
# Processing Record 21 of Set 8 | fort saint james
# Processing Record 22 of Set 8 | sapouy
# Processing Record 23 of Set 8 | ust-tarka
# Processing Record 24 of Set 8 | araxa
# Processing Record 25 of Set 8 | tiarei
# Processing Record 26 of Set 8 | saint-leu
# Processing Record 27 of Set 8 | monticello
# Processing Record 28 of Set 8 | alghero
# Processing Record 29 of Set 8 | yevsino
# Processing Record 30 of Set 8 | qasigiannguit
# Processing Record 31 of Set 8 | the valley
# Processing Record 32 of Set 8 | buqayq
# City not found. Skipping...
# Processing Record 33 of Set 8 | tefe
# Processing Record 34 of Set 8 | sao felix do xingu
# Processing Record 35 of Set 8 | gwadar
# Processing Record 36 of Set 8 | sao jose da coroa grande
# Processing Record 37 of Set 8 | clyde river
# Processing Record 38 of Set 8 | totma
# Processing Record 39 of Set 8 | woodburn
# Processing Record 40 of Set 8 | ceres
# Processing Record 41 of Set 8 | salinopolis
# Processing Record 42 of Set 8 | troitskoye
# Processing Record 43 of Set 8 | prabumulih
# Processing Record 44 of Set 8 | kashi
# Processing Record 45 of Set 8 | kosai
# Processing Record 46 of Set 8 | madawaska
# Processing Record 47 of Set 8 | homer
# Processing Record 48 of Set 8 | santa isabel
# Processing Record 49 of Set 8 | pacific grove
# Processing Record 50 of Set 8 | east london
# Processing Record 1 of Set 9 | scoarta
# Processing Record 2 of Set 9 | ponta do sol
# Processing Record 3 of Set 9 | jining
# Processing Record 4 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 5 of Set 9 | pilao arcado
# City not found. Skipping...
# Processing Record 6 of Set 9 | waingapu
# Processing Record 7 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 9 | vilyuysk
# Processing Record 9 of Set 9 | grand-santi
# Processing Record 10 of Set 9 | ossora
# Processing Record 11 of Set 9 | bure
# Processing Record 12 of Set 9 | antalaha
# Processing Record 13 of Set 9 | nuuk
# Processing Record 14 of Set 9 | yanan
# City not found. Skipping...
# Processing Record 15 of Set 9 | vung tau
# Processing Record 16 of Set 9 | valparaiso
# Processing Record 17 of Set 9 | broome
# Processing Record 18 of Set 9 | ribeira brava
# Processing Record 19 of Set 9 | mehamn
# Processing Record 20 of Set 9 | minab
# Processing Record 21 of Set 9 | paamiut
# Processing Record 22 of Set 9 | constitucion
# Processing Record 23 of Set 9 | waddan
# Processing Record 24 of Set 9 | saint-joseph
# Processing Record 25 of Set 9 | quatre cocos
# Processing Record 26 of Set 9 | bulungu
# Processing Record 27 of Set 9 | hamilton
# Processing Record 28 of Set 9 | gra liyia
# Processing Record 29 of Set 9 | tremedal
# Processing Record 30 of Set 9 | wichian buri
# Processing Record 31 of Set 9 | george town
# Processing Record 32 of Set 9 | dabat
# Processing Record 33 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 34 of Set 9 | aykhal
# Processing Record 35 of Set 9 | santiago del estero
# Processing Record 36 of Set 9 | zhuanghe
# Processing Record 37 of Set 9 | zamora
# Processing Record 38 of Set 9 | norman wells
# Processing Record 39 of Set 9 | quiindy
# Processing Record 40 of Set 9 | marga
# Processing Record 41 of Set 9 | aitape
# Processing Record 42 of Set 9 | vorukh
# Processing Record 43 of Set 9 | sao joao da barra
# Processing Record 44 of Set 9 | bria
# Processing Record 45 of Set 9 | malanje
# Processing Record 46 of Set 9 | manado
# Processing Record 47 of Set 9 | qianjiang
# Processing Record 48 of Set 9 | pacifica
# Processing Record 49 of Set 9 | namibe
# Processing Record 50 of Set 9 | itarema
# Processing Record 1 of Set 10 | agadez
# Processing Record 2 of Set 10 | norden
# Processing Record 3 of Set 10 | tanout
# Processing Record 4 of Set 10 | lavrentiya
# Processing Record 5 of Set 10 | bartica
# Processing Record 6 of Set 10 | mehran
# Processing Record 7 of Set 10 | nouadhibou
# Processing Record 8 of Set 10 | afua
# Processing Record 9 of Set 10 | sangar
# Processing Record 10 of Set 10 | makakilo city
# Processing Record 11 of Set 10 | mayumba
# Processing Record 12 of Set 10 | jackson
# Processing Record 13 of Set 10 | sistranda
# Processing Record 14 of Set 10 | safita
# Processing Record 15 of Set 10 | maceio
# Processing Record 16 of Set 10 | yelan-kolenovskiy
# Processing Record 17 of Set 10 | daund
# Processing Record 18 of Set 10 | vrede
# Processing Record 19 of Set 10 | zyryanka
# Processing Record 20 of Set 10 | ler
# Processing Record 21 of Set 10 | bousso
# Processing Record 22 of Set 10 | berdigestyakh
# Processing Record 23 of Set 10 | kelo
# Processing Record 24 of Set 10 | litovko
# Processing Record 25 of Set 10 | tyup
# Processing Record 26 of Set 10 | burica
# City not found. Skipping...
# Processing Record 27 of Set 10 | poum
# Processing Record 28 of Set 10 | camamu
# Processing Record 29 of Set 10 | kawalu
# Processing Record 30 of Set 10 | le port
# Processing Record 31 of Set 10 | te anau
# Processing Record 32 of Set 10 | mutsu
# Processing Record 33 of Set 10 | victor harbor
# Processing Record 34 of Set 10 | elizabeth city
# Processing Record 35 of Set 10 | saldanha
# Processing Record 36 of Set 10 | san policarpo
# Processing Record 37 of Set 10 | conceicao das alagoas
# Processing Record 38 of Set 10 | whitehorse
# Processing Record 39 of Set 10 | olhao
# Processing Record 40 of Set 10 | saint-augustin
# Processing Record 41 of Set 10 | maragogi
# Processing Record 42 of Set 10 | lufilufi
# Processing Record 43 of Set 10 | abu dhabi
# Processing Record 44 of Set 10 | tautira
# Processing Record 45 of Set 10 | dali
# Processing Record 46 of Set 10 | faya
# Processing Record 47 of Set 10 | chengde
# Processing Record 48 of Set 10 | maltahohe
# Processing Record 49 of Set 10 | rabo de peixe
# Processing Record 50 of Set 10 | marawi
# Processing Record 1 of Set 11 | sile
# Processing Record 2 of Set 11 | ahuimanu
# Processing Record 3 of Set 11 | marsh harbour
# Processing Record 4 of Set 11 | luchegorsk
# Processing Record 5 of Set 11 | nouakchott
# Processing Record 6 of Set 11 | gannan
# Processing Record 7 of Set 11 | kozmodemyansk
# Processing Record 8 of Set 11 | sorland
# Processing Record 9 of Set 11 | palmer
# Processing Record 10 of Set 11 | uyuni
# Processing Record 11 of Set 11 | praia
# Processing Record 12 of Set 11 | san andres
# Processing Record 13 of Set 11 | coruripe
# Processing Record 14 of Set 11 | salinas
# Processing Record 15 of Set 11 | talnakh
# Processing Record 16 of Set 11 | saint-prosper
# Processing Record 17 of Set 11 | teahupoo
# Processing Record 18 of Set 11 | richards bay
# Processing Record 19 of Set 11 | fare
# Processing Record 20 of Set 11 | asosa
# Processing Record 21 of Set 11 | petrozavodsk
# Processing Record 22 of Set 11 | venado tuerto
# Processing Record 23 of Set 11 | morondava
# Processing Record 24 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 11 | vikulovo
# Processing Record 26 of Set 11 | bahia blanca
# Processing Record 27 of Set 11 | san carlos de bariloche
# Processing Record 28 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 11 | bereda
# Processing Record 30 of Set 11 | kokstad
# Processing Record 31 of Set 11 | wanning
# Processing Record 32 of Set 11 | kargasok
# Processing Record 33 of Set 11 | kulhudhuffushi
# Processing Record 34 of Set 11 | maniitsoq
# Processing Record 35 of Set 11 | komnina
# Processing Record 36 of Set 11 | puerto cabezas
# Processing Record 37 of Set 11 | badhni kalan
# Processing Record 38 of Set 11 | mayo
# Processing Record 39 of Set 11 | nanchang
# Processing Record 40 of Set 11 | kalemie
# Processing Record 41 of Set 11 | laela
# Processing Record 42 of Set 11 | samoded
# Processing Record 43 of Set 11 | kenora
# Processing Record 44 of Set 11 | tadine
# Processing Record 45 of Set 11 | prainha
# Processing Record 46 of Set 11 | chatra
# Processing Record 47 of Set 11 | pisco
# Processing Record 48 of Set 11 | sigerfjord
# City not found. Skipping...
# Processing Record 49 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 50 of Set 11 | wewak
# Processing Record 1 of Set 12 | lompoc
# Processing Record 2 of Set 12 | hirado
# Processing Record 3 of Set 12 | chicama
# Processing Record 4 of Set 12 | targu-neamt
# City not found. Skipping...
# Processing Record 5 of Set 12 | herat
# Processing Record 6 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 12 | dawlatabad
# Processing Record 8 of Set 12 | uray
# Processing Record 9 of Set 12 | haines junction
# Processing Record 10 of Set 12 | sohag
# Processing Record 11 of Set 12 | deputatskiy
# Processing Record 12 of Set 12 | severnyy
# Processing Record 13 of Set 12 | baruun-urt
# Processing Record 14 of Set 12 | nizwa
# Processing Record 15 of Set 12 | roebourne
# Processing Record 16 of Set 12 | nazare
# Processing Record 17 of Set 12 | grindavik
# Processing Record 18 of Set 12 | wuda
# Processing Record 19 of Set 12 | banjar
# Processing Record 20 of Set 12 | acapulco
# Processing Record 21 of Set 12 | kotido
# Processing Record 22 of Set 12 | kayes
# Processing Record 23 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 24 of Set 12 | cayenne
# Processing Record 25 of Set 12 | bolshiye chapurniki
# City not found. Skipping...
# Processing Record 26 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 27 of Set 12 | pontianak
# Processing Record 28 of Set 12 | stornoway
# Processing Record 29 of Set 12 | mirandopolis
# Processing Record 30 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 31 of Set 12 | fort nelson
# Processing Record 32 of Set 12 | kuryk
# Processing Record 33 of Set 12 | requena
# Processing Record 34 of Set 12 | saravan
# Processing Record 35 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 36 of Set 12 | wagar
# Processing Record 37 of Set 12 | miraflores
# Processing Record 38 of Set 12 | hofn
# Processing Record 39 of Set 12 | mantua
# Processing Record 40 of Set 12 | banda aceh
# Processing Record 41 of Set 12 | talisay
# Processing Record 42 of Set 12 | dzilam gonzalez
# Processing Record 43 of Set 12 | sawakin
# Processing Record 44 of Set 12 | cravo norte
# Processing Record 45 of Set 12 | ajaccio
# Processing Record 46 of Set 12 | calama
# Processing Record 47 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 12 | palatka
# Processing Record 50 of Set 12 | kurayoshi
# Processing Record 1 of Set 13 | cockburn town
# Processing Record 2 of Set 13 | abha
# Processing Record 3 of Set 13 | harper
# Processing Record 4 of Set 13 | san luis
# Processing Record 5 of Set 13 | vestmanna
# Processing Record 6 of Set 13 | palauig
# Processing Record 7 of Set 13 | bar harbor
# Processing Record 8 of Set 13 | porto novo
# Processing Record 9 of Set 13 | jaisalmer
# Processing Record 10 of Set 13 | road town
# Processing Record 11 of Set 13 | guadalupe y calvo
# Processing Record 12 of Set 13 | wau
# Processing Record 13 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 14 of Set 13 | ponta delgada
# Processing Record 15 of Set 13 | tarauaca
# Processing Record 16 of Set 13 | klaebu
# Processing Record 17 of Set 13 | cap malheureux
# Processing Record 18 of Set 13 | zhongshu
# Processing Record 19 of Set 13 | hualmay
# Processing Record 20 of Set 13 | arman
# Processing Record 21 of Set 13 | balykshi
# Processing Record 22 of Set 13 | buariki
# City not found. Skipping...
# Processing Record 23 of Set 13 | san rafael
# Processing Record 24 of Set 13 | tabora
# Processing Record 25 of Set 13 | pychas
# Processing Record 26 of Set 13 | bathsheba
# Processing Record 27 of Set 13 | rairangpur
# Processing Record 28 of Set 13 | cabedelo
# Processing Record 29 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 30 of Set 13 | cagbang
# Processing Record 31 of Set 13 | marsa matruh
# Processing Record 32 of Set 13 | hanford
# Processing Record 33 of Set 13 | hit
# Processing Record 34 of Set 13 | sibu
# Processing Record 35 of Set 13 | izmalkovo
# Processing Record 36 of Set 13 | waspan
# Processing Record 37 of Set 13 | izumo
# Processing Record 38 of Set 13 | muisne
# Processing Record 39 of Set 13 | ponerihouen
# Processing Record 40 of Set 13 | yumen
# Processing Record 41 of Set 13 | iwanai
# Processing Record 42 of Set 13 | pandelys
# City not found. Skipping...
# Processing Record 43 of Set 13 | chapais
# Processing Record 44 of Set 13 | ballina
# Processing Record 45 of Set 13 | neiafu
# Processing Record 46 of Set 13 | saquarema
# Processing Record 47 of Set 13 | tevaitoa
# Processing Record 48 of Set 13 | poya
# Processing Record 49 of Set 13 | ormara
# Processing Record 50 of Set 13 | basoko
# Processing Record 1 of Set 14 | thunder bay
# Processing Record 2 of Set 14 | miyazu
# Processing Record 3 of Set 14 | tarakan
# Processing Record 4 of Set 14 | viline
# Processing Record 5 of Set 14 | severo-yeniseyskiy
# Processing Record 6 of Set 14 | camrose
# Processing Record 7 of Set 14 | canguaretama
# Processing Record 8 of Set 14 | soyo
# Processing Record 9 of Set 14 | sechenovo
# Processing Record 10 of Set 14 | inhambane
# Processing Record 11 of Set 14 | yerbogachen
# Processing Record 12 of Set 14 | vizinga
# Processing Record 13 of Set 14 | sisimiut
# Processing Record 14 of Set 14 | key largo
# Processing Record 15 of Set 14 | wattegama
# Processing Record 16 of Set 14 | pyay
# Processing Record 17 of Set 14 | bilma
# Processing Record 18 of Set 14 | kachug
# Processing Record 19 of Set 14 | bath
# Processing Record 20 of Set 14 | kosh
# Processing Record 21 of Set 14 | pasca
# Processing Record 22 of Set 14 | jeremie
# Processing Record 23 of Set 14 | tessalit
# Processing Record 24 of Set 14 | novikovo
# Processing Record 25 of Set 14 | elliot
# Processing Record 26 of Set 14 | emerald
# Processing Record 27 of Set 14 | vestmannaeyjar
# Processing Record 28 of Set 14 | trincomalee
# Processing Record 29 of Set 14 | arecibo
# Processing Record 30 of Set 14 | pauini
# Processing Record 31 of Set 14 | saint-denis
# Processing Record 32 of Set 14 | baykit
# Processing Record 33 of Set 14 | awbari
# Processing Record 34 of Set 14 | smithers
# Processing Record 35 of Set 14 | lavumisa
# Processing Record 36 of Set 14 | pitimbu
# Processing Record 37 of Set 14 | avera
# Processing Record 38 of Set 14 | verkhoyansk
# Processing Record 39 of Set 14 | ekhabi
# Processing Record 40 of Set 14 | zhanaozen
# Processing Record 41 of Set 14 | chaman
# Processing Record 42 of Set 14 | linares
# Processing Record 43 of Set 14 | nago
# Processing Record 44 of Set 14 | ondjiva
# Processing Record 45 of Set 14 | surt
# Processing Record 46 of Set 14 | darhan
# Processing Record 47 of Set 14 | borovoy
# Processing Record 48 of Set 14 | platteville
# Processing Record 49 of Set 14 | vitim
# Processing Record 50 of Set 14 | danilov
# Processing Record 1 of Set 15 | espanola
# Processing Record 2 of Set 15 | upington
# Processing Record 3 of Set 15 | asau
# Processing Record 4 of Set 15 | chernyshevskiy
# Processing Record 5 of Set 15 | alcantara
# Processing Record 6 of Set 15 | aleksandrov gay
# Processing Record 7 of Set 15 | port hardy
# Processing Record 8 of Set 15 | tashtyp
# Processing Record 9 of Set 15 | akdepe
# Processing Record 10 of Set 15 | tezu
# Processing Record 11 of Set 15 | la ronge
# Processing Record 12 of Set 15 | lae
# Processing Record 13 of Set 15 | lokoja
# Processing Record 14 of Set 15 | lumberton
# Processing Record 15 of Set 15 | don sak
# Processing Record 16 of Set 15 | honningsvag
# Processing Record 17 of Set 15 | eirunepe
# Processing Record 18 of Set 15 | bairiki
# Processing Record 19 of Set 15 | bubaque
# Processing Record 20 of Set 15 | marzuq
# Processing Record 21 of Set 15 | bodden town
# Processing Record 22 of Set 15 | kodinsk
# Processing Record 23 of Set 15 | olafsvik
# Processing Record 24 of Set 15 | tema
# Processing Record 25 of Set 15 | siyabuswa
# Processing Record 26 of Set 15 | albanel
# Processing Record 27 of Set 15 | jalu
# Processing Record 28 of Set 15 | akcaabat
# Processing Record 29 of Set 15 | toora-khem
# Processing Record 30 of Set 15 | kalabo
# Processing Record 31 of Set 15 | masindi
# Processing Record 32 of Set 15 | alpena
# Processing Record 33 of Set 15 | ukiah
# Processing Record 34 of Set 15 | sao gabriel da cachoeira
# Processing Record 35 of Set 15 | sabang
# Processing Record 36 of Set 15 | pallasovka
# Processing Record 37 of Set 15 | popondetta
# Processing Record 38 of Set 15 | tomohon
# Processing Record 39 of Set 15 | vangaindrano
# Processing Record 40 of Set 15 | puri
# Processing Record 41 of Set 15 | alexandria
# Processing Record 42 of Set 15 | touros
# Processing Record 43 of Set 15 | jasper
# Processing Record 44 of Set 15 | kushima
# Processing Record 45 of Set 15 | bambanglipuro
# Processing Record 46 of Set 15 | erenhot
# Processing Record 47 of Set 15 | ambulu
# Processing Record 48 of Set 15 | nyahururu
# Processing Record 49 of Set 15 | vanimo
# Processing Record 50 of Set 15 | asyut
# Processing Record 1 of Set 16 | camopi
# Processing Record 2 of Set 16 | raudeberg
# Processing Record 3 of Set 16 | amahai
# Processing Record 4 of Set 16 | kota bahru
# Processing Record 5 of Set 16 | wanaka
# Processing Record 6 of Set 16 | umm lajj
# Processing Record 7 of Set 16 | maimon
# City not found. Skipping...
# Processing Record 8 of Set 16 | grand centre
# City not found. Skipping...
# Processing Record 9 of Set 16 | praia da vitoria
# Processing Record 10 of Set 16 | timmins
# Processing Record 11 of Set 16 | machico
# Processing Record 12 of Set 16 | vanderhoof
# Processing Record 13 of Set 16 | shaoyang
# Processing Record 14 of Set 16 | manyana
# Processing Record 15 of Set 16 | lata
# Processing Record 16 of Set 16 | vila franca do campo
# Processing Record 17 of Set 16 | yaan
# Processing Record 18 of Set 16 | putyatino
# Processing Record 19 of Set 16 | port hawkesbury
# Processing Record 20 of Set 16 | babanusah
# City not found. Skipping...
# Processing Record 21 of Set 16 | bull savanna
# Processing Record 22 of Set 16 | sioux lookout
# Processing Record 23 of Set 16 | nadym
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 710

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Jamestown  42.0970  -79.2353     42.53        44           0
# 1       Sao Filipe  14.8961  -24.4956     82.94        49          55
# 2           Torbay  47.6666  -52.7314     35.76        86         100
# 3       Blackwater -23.5833  148.8833     67.68        25          42
# 4     Saint George  37.1041 -113.5841     34.39        51           0
# 5  Arraial Do Cabo -22.9661  -42.0278     84.16        65          40
# 6            Ancud -41.8697  -73.8203     56.16        93         100
# 7     Beringovskiy  63.0500  179.3167     -9.11        97           9
# 8         Hermanus -34.4187   19.2345     69.80        70          59
# 9            Kapaa  22.0752 -159.3190     72.19        86          89
#
#    Wind Speed Country Current Description
# 0       10.36      US           clear sky
# 1       16.73      CV       broken clouds
# 2       19.57      CA          light snow
# 3        8.81      AU    scattered clouds
# 4        4.61      US           clear sky
# 5       28.77      BR    scattered clouds
# 6        9.26      CL          light rain
# 7       13.20      RU           clear sky
# 8        8.84      ZA       broken clouds
# 9        1.01      US     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Jamestown      US  42.0970  -79.2353     42.53        44           0
# 1       Sao Filipe      CV  14.8961  -24.4956     82.94        49          55
# 2           Torbay      CA  47.6666  -52.7314     35.76        86         100
# 3       Blackwater      AU -23.5833  148.8833     67.68        25          42
# 4     Saint George      US  37.1041 -113.5841     34.39        51           0
# 5  Arraial Do Cabo      BR -22.9661  -42.0278     84.16        65          40
# 6            Ancud      CL -41.8697  -73.8203     56.16        93         100
# 7     Beringovskiy      RU  63.0500  179.3167     -9.11        97           9
# 8         Hermanus      ZA -34.4187   19.2345     69.80        70          59
# 9            Kapaa      US  22.0752 -159.3190     72.19        86          89
#
#    Wind Speed Current Description
# 0       10.36           clear sky
# 1       16.73       broken clouds
# 2       19.57          light snow
# 3        8.81    scattered clouds
# 4        4.61           clear sky
# 5       28.77    scattered clouds
# 6        9.26          light rain
# 7       13.20           clear sky
# 8        8.84       broken clouds
# 9        1.01     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index=False)
